# %% [markdown]
# ## <font color='blue'>Matemática Fundamental com Linguagem Python</font>
# ## <font color='blue'>Lista de Exercícios 1</font>

# %% [markdown]
# ### Instalando e Carregando Pacotes

# %%
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark
# !pip install -q -U numpy
# !pip install -q -U matplotlib

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Cleidson Goes" --iversions

# %% [markdown]
# ### Exercício 1: Cálculo de Área de um Círculo
#
# Escreva um programa que calcula a área de um círculo. O usuário deve fornecer o raio e o programa deve retornar a área.

# %%
# Importa o módulo math para acessar constantes e funções matemáticas, como o valor de pi
import math

def area_circulo(raio):

    # Calcula a área do círculo usando a fórmula área = pi * raio^2
    # math.pi fornece o valor de pi
    return math.pi * raio ** 2

# Pede ao usuário para inserir o valor do raio e converte para número ponto flutuante
raio = float(input("Digite o raio do círculo: "))

# Imprime a área do círculo chamando a função acima com o raio fornecido.
print("A área do círculo é:", area_circulo(raio))

# %% [markdown]
# ### Exercício 2: Conversão de Temperatura
#
# Crie uma função que converte a temperatura de Celsius para Fahrenheit e vice-versa. O usuário deve informar a temperatura e a escala de origem.

# %%
def conversor(temp, escala):

    # Verifica se a escala informada é Celsius (transformando a entrada em maiúscula para evitar erros)
    if escala.upper() == "C":

        # Conversão da temperatura para Fahrenheit e impressão do resultado
        fahren = (temp * 9/5) + 32
        print(f"O resultado da conversão é: {fahren}°F")

    # Verifica se a escala informada é Fahrenheit (transformando a entrada em maiúscula para evitar erros)
    elif escala.upper() == "F":

        # Conversão da temperatura para Celsius e impressão do resultado
        Cels = (temp - 32) * 5/9
        print(f"A temperatura informada em Celsius é: {Cels}°C")

    else:
        # Solicita ao usuário que digite C para Celsius ou F para Fahrenheit
        print("Digite a escala C para Celsius ou F para Fahrenheit")

# Solicita ao usuário para inserir uma temperatura e converte a entrada para um número de ponto flutuante
temp = float(input("Digite a temperatura: "))

# Solicita ao usuário para escolher a escala ('C' para Celsius ou 'F' para Fahrenheit)
escala = input("Digite a escala atual, (C para Celsius, F para Fahrenheit): ")


conversor(temp, escala)

# %% [markdown]
# ### Exercício 3: Resolver uma Equação Linear
#
# Faça um programa que resolve uma equação linear do tipo ax + b = 0. Os valores de a e b são fornecidos pelo usuário.

# %%
def resolve_linear(a, b):
    
    # Verifica se 'a' é zero, o que indica uma equação linear degenerada
    if a == 0:

        # Se 'b' também for zero, a equação é indeterminada com soluções infinitas;
        # caso contrário, é uma contradição e não tem solução
        return "Sem solução" if b != 0 else "Soluções infinitas"

    # Se 'a' não é zero, resolve a equação linear ax + b = 0 e retorna a solução x = -b/a
    return -b / a

# Pede ao usuário para inserir o valor do coeficiente 'a' e converte a entrada para um número de ponto flutuante
a = float(input("Digite o valor de a: "))

# Pede ao usuário para inserir o valor do coeficiente 'b' e converte a entrada para um número de ponto flutuante
b = float(input("Digite o valor de b: "))

print("Solução da equação:", resolve_linear(a, b))

# %% [markdown]
# ### Exercício 4: Cálculo de Média Aritmética
#
# Escreva um programa que calcula a média aritmética de uma lista de números fornecida pelo usuário.

# %%
def media_aritmetica(numeros):
    
    # Calcula a média aritmética de uma lista de números somando todos os elementos
    # e dividindo pela quantidade de números
    return sum(numeros) / len(numeros)

# Pede para o usuário para inserir uma lista de números criando uma lista de números ponto flutuante
numbers = [float(n) for n in input("Digite uma lista de números separados por espaço: ").split()]

print("Média aritmética: ", media_aritmetica(numbers))

# %% [markdown]
# ### Exercício 5: Determinar as Raízes de uma Equação Quadrática
#
# Crie um programa que encontra as raízes de uma equação quadrática do tipo ax^2 + bx + c = 0. O programa deve lidar com todos os tipos de raízes (reais e complexas).

# %%
# Importa o módulo cmath para operações matemáticas com números complexos
import cmath

def raizes_quadraticas(a, b, c):

    # Validação para garantir que seja uma equação do segundo grau
    if a == 0:
        return "Não é uma equação do 2° grau"
        
    # Calcula a raiz de delta da equação quadrática usando a fórmula delta = b^2 - 4ac
    # usando o cmath.sqrt para números negativos (números complexos)
    raiz_delta = cmath.sqrt(b**2 - 4*a*c)

    # Calcula a primeira raiz (x1) da equação usando a fórmula  x = (-b + sqrt(delta)) / 2a
    x1 = (-b + raiz_delta) / (2*a)

    # Calcula a segunda raiz (x2) da equação usando a fórmula  x = (-b - sqrt(delta)) / 2a
    x2 = (-b - raiz_delta) / (2*a)

    return (x1, x2)

# Solicita ao usuário para inserir o valor do coeficiente 'a'
a = float(input("Digite o valor de a: "))

# Solicita ao usuário para inserir o valor do coeficiente 'b'
b = float(input("Digite o valor de b: "))

# Solicita ao usuário para inserir o valor do coeficiente 'c'
c = float(input("Digite o valor de c: "))

# Imprime chamando a função raizes_quadraticas com os valores do usuário.
print("As raízes da equação são: ", raizes_quadraticas(a, b, c))

# %% [markdown]
# ### Exercício 6: Calcular o Fatorial de um Número
#
# Escreva uma função que calcula o fatorial de um número inteiro fornecido pelo usuário.

# %%
def fatorial(n):

    # Retorna 1 se n é 0, pois o fatorial de 0 é definido como 1
    # Caso contrário, retorna n multiplicado pelo fatorial de n-1 (chamada recursiva),
    # o que efetivamente constrói o produto n * (n-1) * (n-2) * ...
    return 1 if n == 0 else n * fatorial(n - 1)

# Solicita ao usuário para inserir um número inteiro
num = int(input("Digite um número inteiro: "))

print("Fatorial: ",fatorial(num))

# %% [markdown]
# ### Exercício 7: Sequência de Fibonacci
#
# Crie um programa que gera a sequência de Fibonacci até um determinado número n fornecido pelo usuário.

# %%
def fibonacci(n):

    # Inicializa as duas primeiras variáveis, a e b, que armazenam os dois
    # primeiros números da sequência de Fibonacci
    a, b = 0, 1

    # Um loop que itera n vezes para gerar n termos da sequência
    for _ in range(n):

        # Gera o valor atual de a, que é um termo da sequência de Fibonacci
        yield a

        # Atualiza os valores de a e b para os próximos dois termos na sequência
        # a recebe o valor atual de b, e b recebe a soma dos valores anteriores de a e b
        a, b = b, a + b

n = int(input("Digite o número de termos da sequência de Fibonacci: "))
    
# Imprime a sequência, convertendo o gerador em uma lista para exibir todos os termos gerados
print("Sequência de Fibonacci:", list(fibonacci(n)))

# %% [markdown]
# ### Exercício 8: Cálculo de Juros Compostos
#
# Faça um programa que calcula o montante final de um investimento com juros compostos. O usuário deve fornecer o capital inicial, a taxa de juros anual, e o número de anos.

# %%
def juros_compostos(capital, taxa, anos):

    # Calcula o montante final usando a fórmula de juros compostos: M = C * (1 + r)^t
    # onde M é o montante, C é o capital inicial, r é a taxa de juros, e t o tempo em anos
    return capital * (1 + taxa) ** anos

# Solicita ao usuário para inserir o capital inicial e converte a entrada em um número de ponto flutuante
capital = float(input("Digite o capital inicial: "))

#Solicita ao usuário para inserir a taxa de juros anual (em formato decimal) e converte
# a entrada em um número de ponto flutuante
#Por exemplo, uma taxa de 5% deve ser inserida como 0.05
taxa = float(input("Digite a taxa de juros anual (em decimal): "))

#Solicita ao usuário para inserir o número de anos e converte a entrada em um número inteiro
anos = int(input("Digite o número de anos: "))

#Solicita ao usuário para inserir o número de anos e converte a entrada em um número inteiro
print("O montante final é: ", juros_compostos(capital, taxa, anos))

# %% [markdown]
# ### Exercício 9: Conversão de Moedas
#
# Escreva um programa que converte uma quantidade de uma moeda (como dólar) para outra (como euro), considerando uma taxa de câmbio fornecida pelo usuário.

# %%
def converter_moeda(valor, taxa_cambio):

    # Multiplica o valor na moeda original pela taxa de câmbio para obter o valor na moeda convertida
    return valor * taxa_cambio

# Solicitação ao usuário do valor da moeda e conversão para ponto flutuante
valor = float(input("Digite o valor na moeda original: "))

# Pede ao usuário para inserir a taxa de câmbio e converte para ponto flutuante
taxa_cambio = float(input("Digite a taxa de câmbio: "))

print("Valor convertido: ", converter_moeda(valor, taxa_cambio))

# %% [markdown]
# ### Exercício 10: Verificar se um Número é Primo
#
# Crie uma função que verifica se um número fornecido pelo usuário é primo ou não.

# %%
def e_primo(num):

    # Verifica se o número é meno que 2, pois números menores que 2 não são primos
    if num < 2:
        return False

    # Percorre os números de 2 até a raiz quadrada do número (arredondando para cima).
    # Essa otimização é possível porque se um número tem um divisor maior que sua raiz quadrada,
    # então ele também deve ter um divisor menor que a raiz quadrada.
    for i in range(2, int(num ** 0.5) + 1):

        # Se o número for divisível por i, então ele não é primo
        if num % i == 0:
            return False

    # Se o loop for concluído sem encontrar divisores, o número é primo
    return True

numero = int(input("Digite um número: "))

print("O número é primo!" if e_primo(numero) else "O número não é primo!")

# %% [markdown]
# ### Exercício 11: Representação gráfica de função
#
# Crie uma representação gráfica da função f(x) = x ^ 2

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define a função
def f(x):
    return x ** 2


# Cria um conjunto de valores aleatórios de x (por exemplo, de -10 a 10)
x = np.linspace(-10, 10, 400)

# Calcula os valores de y para cada valor de x
y = f(x)

# %%
# Criação do gráfico
plt.figure(figsize = (6, 4))
plt.plot(x, y, label = 'f(x) = x²')

# Adiciona um título e rótulos aos eixos
plt.title('Gráfico da Função Quadrática')
plt.xlabel('x')
plt.ylabel('f(x)')

# Adiciona uma legenda
plt.legend()

# Mostra o gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercício 12: Seno
#
# Calcule o seno

# %%
# Importa o módulo 'math', que contém funções matemáticas
import math

# Calculando o seno de 30 graus

# Define o ângulo em graus, neste caso 30 graus
angulo_graus = 30

# Converte o ângulo de graus para radianos
angulo_radianos = math.radians (angulo_graus)

# Calcula o seno do ângulo, que agora está em radianos
seno = math.sin(angulo_radianos)

# Exibe o valor do seno de 30 graus
print("Seno de 30°:", seno)

# %% [markdown]
# ### Exercício 13: Cosseno
#
# Calcule o Cosseno de 45 graus

# %%
import math

# calculando o Cosseno de 45 graus

# Define o ângulo em graus, neste caso 45 graus
angulo_graus = 45

# Converte o ângulo de graus para radianos
angulo_radianos = math.radians(angulo_graus)

# Calcula o cosseno do ângulo, que agora está em radianos
cosseno = math.cos(angulo_radianos)

# Exibe o valor do cosseno de 45 graus
print("Cosseno de 45°:", cosseno)

# %% [markdown]
# ### Exercício 14: Tangente
#
# Calcule a tangente de 60 graus

# %%
import math

# Calculando a tangente de 60 graus

# Define o ângulo em graus, neste caso 60 graus
angulo_graus = 60

# Converte o ângulo de graus para radianos
angulo_radianos = math.radians(angulo_graus)

# Calcula o tangente do ângulo, que agora está em radianos
tangente = math.tan(angulo_radianos)

# Exibe o valor do tangente de 60 graus
print("Tangente de 60°:", tangente)

# %% [markdown]
# ### Exercício 14: Aplicar LOG em uma base de dados
#
# Aplicando a transformação de log em um conjunto de dados para normalizá-los usando a biblioteca numpy para manipular os dados e matplotlib para visualização.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gerando dados de exemplo: preços de casas
np.random.seed(0)
preco_casas = np.random.lognormal(mean = 13, sigma = 0.6, size = 1000)

# Aplicando a transformação logarítmica
preco_casas_log = np.log(preco_casas)

# Criando os gráficos para comparação
plt.figure(figsize = (8, 4))

# Gráfico dos dados originais
plt.subplot(1, 2, 1)
plt.hist(preco_casas, bins = 30, color = 'blue', alpha = 0.7)
plt.title('Distribuição dos Preços das Casas')
plt.xlabel('Preço')
plt.ylabel('Frequência')

# Gráfico dos dados transformados
plt.subplot(1, 2, 2)
plt.hist(preco_casas_log, bins = 30, color = 'green', alpha = 0.7)
plt.title('Distribuição Logarítmica dos Preços das Casas')
plt.xlabel('Log do Preço')
plt.ylabel('Frequência')

plt.tight_layout()
plt.show()
